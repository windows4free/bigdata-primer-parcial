# %% [markdown]
# ## Ejercicio 1: Clasificación de edad
#
# **Enunciado:** determinar si una persona es niño, adolescente, adulto o adulto mayor según su edad.
#
# **Lógica:** se evalúa la edad con condiciones `if`, `elif` y `else`. El primer rango que se cumple determina la categoría.

# %%
def clasificar_edad(edad):

    if edad < 13:
        return "Niño"

    elif edad <= 17:
        return "Adolescente"

    elif edad <= 59:
        return "Adulto"

    else:
        return "Adulto mayor"


edad = 21

categoria = clasificar_edad(edad)

print(f"Edad: {edad} años")
print(f"Categoría: {categoria}")
# Out:
# Edad: 21 años
# Categoría: Adulto

# %% [markdown]
# ## Ejercicio 2: Conversor de temperatura
#
# **Enunciado:** convertir una temperatura de grados Celsius a Fahrenheit.
#
# **Lógica:** se guarda la temperatura en una variable y se aplica la fórmula `F = (C × 9/5) + 32` para obtener el resultado.

# %%
def convertir_fahrenheit(celsius):

    fahrenheit = (celsius * 9/5) + 32

    return fahrenheit


temperatura_celsius = 40

resultado = convertir_fahrenheit(temperatura_celsius)

print(f"Temperatura en Celsius: {temperatura_celsius}°C")
print(f"Temperatura en Fahrenheit: {resultado}°F")
# Out:
# Temperatura en Celsius: 40°C
# Temperatura en Fahrenheit: 104.0°F

# %% [markdown]
# ## Ejercicio 3: Calculadora básica
#
# **Enunciado:** realizar operaciones matemáticas básicas entre dos números.
#
# **Lógica:** se usan condiciones `if/elif/else` para determinar qué operación ejecutar. Además se valida que el divisor no sea `0` para evitar errores.

# %%
def calculadora(num1, num2, operacion):

    if operacion == "+":
        return num1 + num2

    elif operacion == "-":
        return num1 - num2

    elif operacion == "*":
        return num1 * num2

    elif operacion == "/":

        if num2 != 0:
            return num1 / num2

        else:
            return "Error: división entre cero"

    else:
        return "Operación no válida"


numero1 = 30
numero2 = 7
operacion = "*"

resultado = calculadora(numero1, numero2, operacion)

print(f"Número 1: {numero1}")
print(f"Número 2: {numero2}")
print(f"Operación: {operacion}")
print(f"Resultado: {resultado}")
# Out:
# Número 1: 30
# Número 2: 7
# Operación: *
# Resultado: 210

# %% [markdown]
# ## Ejercicio 4: Número par o impar
#
# **Enunciado:** determinar si un número entero es par o impar.
#
# **Lógica:** se utiliza el operador módulo `%`, el cual permite obtener el residuo de una división. Si un número dividido entre 2 deja residuo `0` es par, si deja residuo diferente de `0` es impar.

# %%
def verificar_par_impar(numero):
    if numero % 2 == 0:
        return "Par"
    else:
        return "Impar"


numero = 15
resultado = verificar_par_impar(numero)

print(f"Número: {numero}")
print(f"Resultado: El número es {resultado}")
# Out:
# Número: 15
# Resultado: El número es Impar

# %% [markdown]
# ## Ejercicio 5: Tabla de multiplicar
#
# **Enunciado:** generar la tabla de multiplicar de un número entero del 1 al 12.
#
# **Lógica:** se define un número entero y se utiliza un ciclo `for` para repetir el proceso desde el 1 hasta el 12. En cada repetición el número se multiplica por el valor actual del ciclo y se muestra el resultado.

# %%
def tabla_multiplicar(numero):
    for i in range(1, 13):
        resultado = numero * i
        print(f"{numero} x {i} = {resultado}")


numero = 9

print(f"Tabla de multiplicar del {numero}")
tabla_multiplicar(numero)
# Out:
# Tabla de multiplicar del 9
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90
# 9 x 11 = 99
# 9 x 12 = 108

# %% [markdown]
# ## Ejercicio 6: Contador de vocales
#
# **Enunciado:** contar cuántas vocales contiene una frase.
#
# **Lógica:** se define una frase y se convierte a minúsculas con `.lower()` para detectar vocales sin importar si están en mayúsculas o minúsculas. Luego se recorre cada letra con un ciclo `for` y se verifica si pertenece al conjunto de vocales.

# %%
def contar_vocales(frase):
    vocales = "aeiou"
    contador = 0

    for letra in frase.lower():
        if letra in vocales:
            contador += 1

    return contador


frase = "Este es un ejercicio para contar vocales."
cantidad_vocales = contar_vocales(frase)

print(f"Frase: {frase}")
print(f"Cantidad de vocales: {cantidad_vocales}")
# Out:
# Frase: Este es un ejercicio para contar vocales.
# Cantidad de vocales: 16

# %% [markdown]
# ## Ejercicio 7: Promedio de calificaciones
#
# **Enunciado:** calcular el promedio de 5 calificaciones e indicar si el estudiante aprobó o reprobó.
#
# **Lógica:** se usa `sum()` para sumar todas las calificaciones y `len()` para obtener la cantidad, luego se divide para obtener el promedio y se evalúa con `if/else` si es mayor o igual a 70.

# %%
calificaciones = [85, 90, 60, 75, 80]

suma = sum(calificaciones)
promedio = suma / 5

print(f"Suma total: {suma}")
print(f"Promedio: {promedio}")

if promedio >= 70:
    print("El estudiante APROBÓ")
else:
    print("El estudiante REPROBÓ")
# Out:
# Suma total: 390
# Promedio: 78.0
# El estudiante APROBÓ

# %% [markdown]
# ## Ejercicio 8: Lista de números positivos y negativos
#
# **Enunciado:** clasificar 10 números contando cuántos son positivos, negativos y ceros.
#
# **Lógica:** se recorre una lista con un ciclo `for` y se evalúa cada número con `if/elif/else` para sumar al contador de cada categoría.

# %%
numeros = [4, -2, 0, 7, -5, 0, 3, -1, 8, -9]

positivos = 0
negativos = 0
ceros = 0

for n in numeros:
    if n > 0:
        positivos += 1
    elif n < 0:
        negativos += 1
    else:
        ceros += 1

print(f"Positivos: {positivos}")
print(f"Negativos: {negativos}")
print(f"Ceros: {ceros}")
# Out:
# Positivos: 4
# Negativos: 4
# Ceros: 2

# %% [markdown]
# ## Ejercicio 9: Mayor y menor de una lista
#
# **Enunciado:** encontrar el número mayor y menor de una lista y calcular la diferencia entre ambos.
#
# **Lógica:** se usan las funciones `max()` y `min()` que recorren la lista automáticamente y devuelven el valor más alto y más bajo respectivamente.

# %%
numeros = [15, 3, 42, 8, 27, 5, 99, 11]

mayor = max(numeros)
menor = min(numeros)
diferencia = mayor - menor

print(f"Mayor: {mayor}")
print(f"Menor: {menor}")
print(f"Diferencia: {diferencia}")
# Out:
# Mayor: 99
# Menor: 3
# Diferencia: 96

# %% [markdown]
# ## Ejercicio 10: Diccionario de estudiante
#
# **Enunciado:** almacenar la información de un estudiante en un diccionario.
#
# **Lógica:** se definen los datos del estudiante en un diccionario y se utiliza una condición `if/else` para determinar si está **Aprobado** o **Reprobado** según su promedio.

# %%
datos = {
    "nombre": "David Alvarado",
    "edad": 21,
    "carrera": "Ingeniería en Ciencias de la Computacion",
    "promedio": 69,
}

if datos["promedio"] < 70:
    estado = "Reprobado"
else:
    estado = "Aprobado"
    
print("DATOS DEL ESTUDIANTE")
print(f"Nombre   : {datos['nombre']}")
print(f"Edad     : {datos['edad']}")
print(f"Carrera  : {datos['carrera']}")
print(f"Promedio : {datos['promedio']}")
print(f"Estado   : {estado}")
# Out:
# DATOS DEL ESTUDIANTE
# Nombre   : David Alvarado
# Edad     : 21
# Carrera  : Ingeniería en Ciencias de la Computacion
# Promedio : 69
# Estado   : Reprobado

# %% [markdown]
# ## Ejercicio 11: Función para calcular descuento
#
# **Enunciado:** crear una función que calcule el precio final de un producto aplicando un descuento.
#
# **Lógica:** la función recibe el precio original y el porcentaje de descuento. Multiplica el precio por el porcentaje para obtener el valor del descuento, luego resta ese valor al precio original y retorna el precio final.

# %%
def calcular_descuento(precio_original, porcentaje_descuento):
    descuento = precio_original * (porcentaje_descuento / 100)
    precio = precio_original - descuento
    return precio

precio_final = calcular_descuento(100, 20)

print("Precio final:", precio_final)
# Out:
# Precio final: 80.0

# %% [markdown]
# ## Ejercicio 12: Validación de contraseña
#
# **Enunciado:** validar si una contraseña ingresada por el usuario cumple con los requisitos mínimos de seguridad.
#
# **Lógica:** el programa verifica que la contraseña tenga al menos **8 caracteres**, al menos **1 número**, al menos **1 mayúscula** y **1 minúscula**. Si se cumplen todas las condiciones muestra un mensaje indicando si la contraseña es válida o no.

# %%
contraseña = "BigData123"

cantidad = len(contraseña) >= 8
tiene_numero = any(caracter.isdigit() for caracter in contraseña)
tiene_mayuscula = any(caracter.isupper() for caracter in contraseña)
tiene_minuscula = any(caracter.islower() for caracter in contraseña)

if cantidad and tiene_numero and tiene_mayuscula and tiene_minuscula:
    print("La contraseña es válida")
else:
    print("La contraseña NO es válida")
# Out:
# La contraseña es válida

# %% [markdown]
# ## Ejercicio 13: Sistema simple de inventario
#
# **Enunciado:** crear un sistema básico que almacene y muestre los productos de un inventario.
#
# **Lógica:** se crea una lista donde cada elemento es un diccionario con las claves `código`, `nombre`, `precio` y `cantidad`. Se recorre la lista con un ciclo `for` para mostrar la información de cada producto.

# %%
productos = [
    {"codigo": 1, "nombre": "Lápiz", "precio": 0.5, "cantidad": 100},
    {"codigo": 2, "nombre": "Cuaderno", "precio": 2.0, "cantidad": 50},
    {"codigo": 3, "nombre": "Goma", "precio": 0.3, "cantidad": 80},
]

# Mostrar todos
print("Inventario:")
for p in productos:
    print(f"Código:{p['codigo']} - {p['nombre']} - ${p['precio']} - {p['cantidad']} uds")

codigo_buscar = 2
encontrado = None
for p in productos:
    if p["codigo"] == codigo_buscar:
        encontrado = p
        break

if encontrado:
    print(f"\nProducto encontrado: {encontrado['nombre']}, Precio: ${encontrado['precio']}, Stock: {encontrado['cantidad']}")
else:
    print("\nNo existe ese código")

total = sum(p["precio"] * p["cantidad"] for p in productos)
print(f"\nValor total del inventario: ${total}")
# Out:
# Inventario:
# Código:1 - Lápiz - $0.5 - 100 uds
# Código:2 - Cuaderno - $2.0 - 50 uds
# Código:3 - Goma - $0.3 - 80 uds
#
# Producto encontrado: Cuaderno, Precio: $2.0, Stock: 50
#
# Valor total del inventario: $174.0

# %% [markdown]
# ## Ejercicio 14: Registro de ventas
#
# **Enunciado:** registrar y mostrar un conjunto de ventas realizadas.
#
# **Lógica:** se utiliza una lista de diccionarios para almacenar cada venta con su información. Se recorre la lista con un ciclo `for` para mostrar el detalle de cada registro.

# %%
ventas = [
    {"cliente": "María", "producto": "Camisa", "cantidad": 2, "precio_unitario": 15},
    {"cliente": "Juan", "producto": "Pantalón", "cantidad": 1, "precio_unitario": 30},
    {"cliente": "María", "producto": "Zapatos", "cantidad": 1, "precio_unitario": 45},
    {"cliente": "Ana", "producto": "Bufanda", "cantidad": 3, "precio_unitario": 8},
]

for venta in ventas:
    venta["total"] = venta["cantidad"] * venta["precio_unitario"]

total_general = sum(v["total"] for v in ventas)

venta_max = max(ventas, key=lambda v: v["total"])
cliente_top = venta_max["cliente"]
monto_top = venta_max["total"]

print("Ventas detalladas:")
for v in ventas:
    print(f"{v['cliente']} compró {v['cantidad']} {v['producto']}(s) - Total: ${v['total']}")
print(f"\nTotal general vendido: ${total_general}")
print(f"Cliente con la compra más alta: {cliente_top} (${monto_top})")
# Out:
# Ventas detalladas:
# María compró 2 Camisa(s) - Total: $30
# Juan compró 1 Pantalón(s) - Total: $30
# María compró 1 Zapatos(s) - Total: $45
# Ana compró 3 Bufanda(s) - Total: $24
#
# Total general vendido: $129
# Cliente con la compra más alta: María ($45)

# %% [markdown]
# # Ejercicio 15: Limpieza básica de texto
# **Lógica:** se usa `strip()` para eliminar espacios de los extremos, `lower()` para convertir todo a minúsculas, `split()` para dividir la frase en una lista de palabras y `len()` para contar los elementos de esa lista.

# %%
frase = "  Hola   Mundo  esto  es  Python  "

frase = frase.strip()
frase = frase.lower()
while "  " in frase:
    frase = frase.replace("  ", " ")
palabras = frase.split()
print("Frase limpia:", frase)
print("Cantidad de palabras:", len(palabras))
# Out:
# Frase limpia: hola mundo esto es python
# Cantidad de palabras: 5
